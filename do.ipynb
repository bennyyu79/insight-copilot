# %% [markdown]
# ### macos

# %%
python -m venv .venv
source .venv/bin/activate  # On Windows: .venv\Scripts\activate

# %% [markdown]
# ### 1.后端

# %%
export UV_INDEX_URL=https://pypi.tuna.tsinghua.edu.cn/simple

uv pip install -r backend/requirements.txt

# %%
uvicorn backend.app.main:app --reload

# %%
后端使用.env里面的OPENAILIKED_MODEL替换openai模型

.env里面是OPENAILIKED_MODEL模型，提供了OPENAILIKED_API_KEY和OPENAILIKED_BASE_URL

# %% [markdown]
# ### 2. 前端

# %%
cd frontend

pnpm install 

pnpm run dev

# %%
前端使用frontend/.env.local里面的OPENAILIKED_MODEL替换openai模型
